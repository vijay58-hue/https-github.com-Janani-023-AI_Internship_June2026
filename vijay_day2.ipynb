# %%
#id card
name=input("enter the name :")
age=int(input("enter the age :"))
department=input("enter the department :")
salary=int(input("enter the salary :"))
print("name",name)
print("age",age)
print("department",department)
print("salary",salary)
# Out:
# enter the name :vijay
# enter the age :19
# enter the department :bsc
# enter the salary :10000
# name vijay
# age 19
# department bsc
# salary 10000

# %%
#grocery bill
a=int(input("items1:"))
b=int(input("items2:"))
c=int(input("items3:"))
d=int(input("items4:"))
e=int(input("items5:"))
bill=a+b+c+d+e
print("bill=",bill)
# Out:
# items1:99
# items2:199
# items3:69
# items4:55
# items5:50
# bill= 472

# %%
#student mark
a=int(input("mark 1:"))
b=int(input("mark 2:"))
c=int(input("mark 3:"))
d=int(input("mark 4:"))
e=int(input("mark 5:"))
total=a+b+c+d+e
print("total=",total)
# Out:
# mark 1:69
# mark 2:88
# mark 3:99
# mark 4:47
# mark 5:55
# total= 358

# %%
#temperature
a=float(input("celsius"))
b=a*(9/5)+40
print("fahrenheit=",b)
# Out:
# celsius10
# fahrenheit= 58.0

# %%
#recharge
amount=float(input("recharge amt:"))
gst=float(input("gst %:"))
total=amount+(amount*gst/100)
print("total amt",total)
# Out:
# recharge amt:299
# gst %:5
# total amt 313.95

# %%
#bank balance
a=float(input("enter balance:"))
b=float(input("enter amount:"))
if b<=a:
  print("successful")
else:
  print("not successful")
# Out:
# enter balance:1000
# enter amount:5000
# not successful

# %%
#vote
age=int(input("enter the age:"))
if age>=18:
  print("eligble to vote ")
else:
  print("not eligble to vote")
# Out:
# enter the age:20
# eligble to vote

# %%
#discount
amount=int(input("enter purchase amt:"))
if amount>2000:
  discount=a*0.20
elif amount>1000:
  discount=amount*0.10
else:
  discount=0
print("discount:",discount)
print("final amt:",amount-discount)
# Out:
# enter purchase amt:1500
# discount: 150.0
# final amt: 1350.0

# %%
#movie ticket
a=int(input("enter the age:"))
if a>=18:
  print("eligble to ticket")
else:
  print("free ticket")
# Out:
# enter the age:10
# free ticket
