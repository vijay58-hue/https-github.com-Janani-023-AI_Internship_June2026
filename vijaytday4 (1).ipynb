# %%
n="vijay"
print (n[0:3])
# Out:
# vij

# %%
n="vijay"
print(n.upper())
print(n.lower())
print(n.capitalize())
print(n.title())
print(n.swapcase())
# Out:
# VIJAY
# vijay
# Vijay
# Vijay
# VIJAY

# %%
n="vijay sk"
print(n.center(30))
print(n.ljust(30))
print(n.rjust(40))
print("".zfill(10))
# Out:
#            vijay sk
# vijay sk
#                                 vijay sk
# 0000000000

# %%
n="      vijay      "
print(n.strip())
print(n.lstrip())
print(n.rstrip())
# Out:
# vijay
# vijay
#       vijay

# %%
n="vijay sk"
print(n.split())

m="vijaysk"
print(m.split("y"))

s="vijay"
print(s.rsplit("a"))
# Out:
# ['vijay', 'sk']
# ['vija', 'sk']
# ['vij', 'y']

# %%
n="vijay sk"
print(n.find("i"))
print(n.index("k"))
print(n.count("s"))
print(n.startswith("i"))
print(n.endswith("k"))
# Out:
# 1
# 7
# 1
# False
# True

# %%
name="vijay"
age="18"
weight="55"
height="160"
clg="eccs"
print(f"my name is {name} and my age is {age} and my weight is {weight}.  my height is {height} and i am studyinag in {clg}")
# Out:
# my name is vijay and my age is 18 and my weight is 55.  my height is 160 and i am studyinag in eccs

# %%
n="Vijay Sk"
print(n.isalpha())
print(n.isalnum())
print(n.isdigit())
print(n.islower())
print(n.isupper())
print(n.istitle())
# Out:
# False
# False
# False
# False
# False
# True
